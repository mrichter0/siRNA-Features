# %%
data = [
    ("Acoustics", 3.7),
    ("Acta Microbiologica Hellenica", 0.2),
    ("Actuators", 3.9),
    ("Administrative Sciences", 4.8),
    ("Adolescents", 1.3),
    ("Advances in Respiratory Medicine", 2.6),
    ("Aerospace", 3.4),
    ("Agriculture", 4.9),
    ("AgriEngineering", 4.7),
    ("Agronomy", 6.2),
    ("AI", 7.2),
    ("Algorithms", 4.1),
    ("Analytica", 1.8),
    ("Animals", 4.9),
    ("Antibiotics", 7.3),
    ("Antibodies", 7.1),
    ("Antioxidants", 10.6),
    ("Applied Mechanics", 2.3),
    ("Applied Sciences", 5.3),
    ("Applied System Innovation", 7.9),
    ("AppliedMath", None),
    ("Architecture", None),
    ("Arts", None),
    ("Atmosphere", 4.6),
    ("Atoms", 2.7),
    ("Audiology Research", 2.3),
    ("Automation", 2.9),
    ("Axioms", None),
    ("Batteries", 4.0),
    ("Behavioral Sciences", 2.6),
    ("Beverages", 6.1),
    ("Big Data and Cognitive Computing", 7.1),
    ("Bioengineering", 4.0),
    ("Biology", 5.7),
    ("Biomechanics", 1.5),
    ("Biomedicines", 5.2),
    ("Biomimetics", 3.5),
    ("Biomolecules", 9.4),
    ("Biophysica", 1.6),
    ("Biosensors", 6.6),
    ("BioTech", 3.7),
    ("Birds", 2.5),
    ("Brain Sciences", 4.8),
    ("Buildings", 3.4),
    ("C", 1.6),
    ("Cancers", 8.0),
    ("Cardiogenetics", None),
    ("Catalysts", 6.8),
    ("Cells", 9.9),
    ("Ceramics", 3.0),
    ("ChemEngineering", 4.0),
    ("Chemistry", 3.2),
    ("Chemosensors", 5.0),
    ("Children", 2.7),
    ("CivilEng", 2.8),
    ("Clean Technologies", 6.1),
    ("Climate", 5.5),
    ("Clinical and Translational Neuroscience", None),
    ("Clinics and Practice", 2.6),
    ("Clocks & Sleep", 4.4),
    ("Coatings", 5.0),
    ("Colloids and Interfaces", 3.9),
    ("Compounds", 2.3),
    ("Computation", 3.5),
    ("Computers", 5.4),
    ("Condensed Matter", 2.9),
    ("Conservation", None),
    ("Corrosion and Materials Degradation", 4.5),
    ("Cosmetics", 5.2),
    ("COVID", None),
    ("Crops", None),
    ("Cryptography", 3.8),
    ("Crystals", 4.2),
    ("Current Issues in Molecular Biology", 2.9),
    ("Current Oncology", 3.3),
    ("Dairy", 4.4),
    ("Data", 4.3),
    ("Dentistry Journal", 3.7),
    ("Dermatopathology", None),
    ("Diabetology", 2.5),
    ("Diagnostics", 4.7),
    ("Disabilities", 1.1),
    ("Diseases", 0.8),
    ("Diversity", 3.4),
    ("Drones", 5.6),
    ("Dynamics", 1.2),
    ("Earth", 3.3),
    ("Ecologies", 1.8),
    ("Econometrics", 2.4),
    ("Economies", 4.0),
    ("Education Sciences", 4.8),
    ("Electricity", 4.8),
    ("Electronics", 5.3),
    ("Energies", 6.2),
    ("Eng", 2.1),
    ("Entropy", 4.9),
    ("Environments", 5.7),
    ("Epidemiologia", 3.6),
    ("Epigenomes", 3.8),
    ("European Burn Journal", None)
]


data.extend([
    ("European Journal of Investigation in Health, Psychology and Education", 4.4),
    ("Fermentation", 3.8),
    ("Fibers", 7.0),
    ("Fire", 3.1),
    ("Fishes", 1.9),
    ("Fluids", 3.4),
    ("Foods", 7.4),
    ("Forecasting", 5.8),
    ("Forests", 4.4),
    ("Fractal and Fractional", 4.6),
    ("Future Internet", 7.1),
    ("Future Transportation", 2.6),
    ("Galaxies", 4.9),
    ("Games", 1.6),
    ("Gastroenterology Insights", 2.8),
    ("Gastrointestinal Disorders", 1.5),
    ("Gels", 4.7),
    ("Genealogy", 0.4),
    ("Genes", 5.2),
    ("Geographies", 1.7),
    ("GeoHazards", 2.6),
    ("Geosciences", 5.3),
    ("Geriatrics", 3.3),
    ("Healthcare", 3.5),
    ("Hemato", 1.3),
    ("Hematology Reports", 0.9),
    ("Heritage", 2.9),
    ("Horticulturae", 3.5),
    ("Humanities", 0.6),
    ("Hydrogen", 3.6),
    ("Hydrology", 4.9),
    ("Immuno", 2.6),
    ("Infectious Disease Reports", 5.1),
    ("Informatics", 6.6),
    ("Information", 6.9),
    ("Infrastructures", 5.2),
    ("Inorganics", 2.8),
    ("Insects", 5.1),
    ("International Journal of Financial Studies", 3.7),
    ("International Journal of Molecular Sciences", 8.1),
    ("International Journal of Neonatal Screening", 6.7),
    ("International Journal of Plant Biology", 2.0),
    ("International Journal of Turbomachinery, Propulsion and Power", 2.3),
    ("Inventions", 4.8),
    ("IoT", 8.5),
    ("ISPRS International Journal of Geo-Information", 6.9),
    ("Journal of Cardiovascular Development and Disease", 2.6),
    ("Journal of Clinical Medicine", 5.7),
    ("Journal of Composites Science", 5.0),
    ("Journal of Developmental Biology", 4.1),
    ("Journal of Functional Biomaterials", 4.6),
    ("Journal of Functional Morphology and Kinesiology", 4.2),
    ("Journal of Fungi", 6.7),
    ("Journal of Imaging", 5.9),
    ("Journal of Intelligence", 2.8),
    ("Journal of Low Power Electronics and Applications", 3.6),
    ("Journal of Manufacturing and Materials Processing", 5.1),
    ("Journal of Marine Science and Engineering", 4.4),
    ("Journal of Sensor and Actuator Networks", 7.9),
    ("Journal of Theoretical and Applied Electronic Commerce Research", 9.5),
    ("Journal of Xenobiotics", 5.3),
    ("Journal of Zoological and Botanical Gardens", 3.0),
    ("Journalism and Media", 2.6),
    ("Land", 4.9),
    ("Languages", 1.4),
    ("Laws", 2.0),
    ("Life", 4.3),
    ("Logistics", 6.6),
    ("Lubricants", 3.6),
    ("Machine Learning and Knowledge Extraction", 6.3),
    ("Machines", 3.0),
    ("Macromol", 5.2),
    ("Magnetochemistry", 3.9),
    ("Marine Drugs", 9.6),
    ("Materials", 5.8),
    ("Mathematics", 4.0),
    ("Medicina", 3.3),
    ("Membranes", 6.1),
    ("Metabolites", 5.7),
    ("Metals", 4.9),
    ("Methods and Protocols", 3.6),
    ("Microbiology Research", 1.9),
    ("Micromachines", 5.2),
    ("Microorganisms", 7.4),
    ("Minerals", 4.1),
    ("Modelling", 2.7),
])

data.extend([
    ("Molbank", 0.6),
    ("Molecules", 4.2),
    ("Multimodal Technologies and Interaction", 2.4),
    ("Nanomaterials", 4.4),
    ("Neurology International", 3.2),
    ("NeuroSci", 1.6),
    ("Nitrogen", 1.6),
    ("Non-Coding RNA", 3.6),
    ("Nursing Reports", 2.4),
    ("Nutrients", 4.8),
    ("Oceans", 1.5),
    ("Optics", 1.1),
    ("Organics", 1.4),
    ("Parasitologia", None),
    ("Particles", 1.7),
    ("Pathogens", 3.3),
    ("Pathophysiology", 2.7),
    ("Pediatric Reports", 1.4),
    ("Pharmaceuticals", 4.3),
    ("Pharmaceutics", 4.9),
    ("Pharmacy", 2.0),
    ("Philosophies", 0.6),
    ("Photochem", None),
    ("Photonics", 2.1),
    ("Physchem", None),
    ("Physics", 1.5),
    ("Physiologia", None),
    ("Plants", 4.0),
    ("Plasma", 1.9),
    ("Polymers", 4.7),
    ("Polysaccharides", 4.7),
    ("Processes", 2.8),
    ("Prosthesis", 2.8),
    ("Proteomes", 4.0),
    ("Psychiatry International", 1.2),
    ("Publications", 4.6),
    ("Quantum Beam Science", 1.3),
    ("Quaternary", 2.3),
    ("Reactions", 2.2),
    ("Recycling", 4.6),
    ("Religions", 0.7),
    ("Remote Sensing", 4.2),
    ("Reports", 0.8),
    ("Reproductive Medicine", 1.1),
    ("Resources", 3.6),
    ("Risks", 2.0),
    ("Robotics", 2.9),
    ("Safety", 1.8),
    ("Scientia Pharmaceutica", 2.3),
    ("Sensors", 3.4),
    ("Separations", 2.5),
    ("Sexes", 1.2),
    ("Signals", None),
    ("Smart Cities", 7.0),
    ("Social Sciences", 1.7),
    ("Societies", 1.7),
    ("Soil Systems", 2.9),
    ("Solids", 2.4),
    ("Sports", 2.2),
    ("Stats", 0.9),
    ("Surfaces", 2.3),
    ("Surgeries", None),
    ("Surgical Techniques Development", 0.1),
    ("Sustainability", 3.3),
    ("Symmetry", 2.2),
    ("Systems", 2.3),
    ("Taxonomy", None),
    ("Technologies", 4.2),
    ("Telecom", 2.1),
    ("Thalassemia Reports", 0.6),
    ("Thermo", None),
    ("Tomography", 2.2),
    ("Toxics", 3.9),
    ("Toxins", 3.9),
    ("Tropical Medicine and Infectious Disease", 2.8),
    ("Universe", 2.5),
    ("Urban Science", 2.1),
    ("Vaccines", 5.2),
    ("Vehicles", 2.4),
    ("Veterinary Sciences", 2.0),
    ("Vibration", 1.9),
    ("Viruses", 3.8),
    ("Vision", None),
    ("Water", 3.0),
    ("World Electric Vehicle Journal", 2.6),
])

# %%
filtered_data = sorted([(name, value) for name, value in data if value is not None], key=lambda x: x[1])

# %%
top_30 = filtered_data[30:]
print(top_30)
# Out:
# [('Games', 1.6), ('NeuroSci', 1.6), ('Nitrogen', 1.6), ('Geographies', 1.7), ('Particles', 1.7), ('Social Sciences', 1.7), ('Societies', 1.7), ('Analytica', 1.8), ('Ecologies', 1.8), ('Safety', 1.8), ('Fishes', 1.9), ('Microbiology Research', 1.9), ('Plasma', 1.9), ('Vibration', 1.9), ('International Journal of Plant Biology', 2.0), ('Laws', 2.0), ('Pharmacy', 2.0), ('Risks', 2.0), ('Veterinary Sciences', 2.0), ('Eng', 2.1), ('Photonics', 2.1), ('Telecom', 2.1), ('Urban Science', 2.1), ('Reactions', 2.2), ('Sports', 2.2), ('Symmetry', 2.2), ('Tomography', 2.2), ('Applied Mechanics', 2.3), ('Audiology Research', 2.3), ('Compounds', 2.3), ('International Journal of Turbomachinery, Propulsion and Power', 2.3), ('Quaternary', 2.3), ('Scientia Pharmaceutica', 2.3), ('Surfaces', 2.3), ('Systems', 2.3), ('Econometrics', 2.4), ('Multimodal Technologies and Interaction', 2.4), ('Nursing Reports', 2.4), ('Solids', 2.4), ('Vehicles', 2.4), ('Birds', 2.5), ('Diabetology', 2.5), ('Separations', 2
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

raw_data_6 = pd.read_csv('rawdata_ref_cif/raw_data_6.csv')
print(f"Original number of rows: {len(raw_data_6)}")

data_dropped = raw_data_6.drop(columns="22")

entries_to_remove = [
    "ENSG00000202515_amide",
    "ENSG00000210107_amide",
    "ENSG00000275708_amide",
    "ENSG00000202515_gna",
    "ENSG00000210107_gna",
    "ENSG00000275708_gna",
    "ENSG00000202515_unmod",
    "ENSG00000210107_unmod",
    "ENSG00000275708_unmod"
]

raw_data_6_updated = data_dropped[~data_dropped['comp_name'].isin(entries_to_remove)]
print(f"Number of rows after removal: {len(raw_data_6_updated)}")
print(raw_data_6_updated)

min_values = raw_data_6_updated.min(numeric_only=True)
max_values = raw_data_6_updated.max(numeric_only=True)

# Plot min values for each column
fig1, ax1 = plt.subplots()
ax1.plot(min_values.index, min_values.values, label='Min', marker='o')
ax1.set_xticks(range(len(min_values.index)))
ax1.set_xticklabels(min_values.index, rotation=45, ha='right')
ax1.set_title('Min Values for Each Column')
plt.tight_layout()

# Plot max values for each column
fig2, ax2 = plt.subplots()
ax2.plot(max_values.index, max_values.values, label='Max', marker='o')
ax2.set_xticks(range(len(max_values.index)))
ax2.set_xticklabels(max_values.index, rotation=45, ha='right')
ax2.set_title('Max Values for Each Column')
plt.tight_layout()

plt.show()
# Out:
# Original number of rows: 33714
# Number of rows after removal: 33705
#                    comp_name      23      24      25      26      27      28  \
# 0      ENSG00000000003_amide  0.8100  0.7692  0.8329  0.8946  0.6849  0.4803
# 1      ENSG00000000419_amide  0.9973  1.0123  0.8756  0.6735  0.6364  0.5919
# 2      ENSG00000000457_amide  1.2167  1.3442  1.3036  1.1560  1.1697  1.0354
# 3      ENSG00000000460_amide  1.4809  1.5021  1.3357  1.0627  1.0352  0.8848
# 4      ENSG00000000971_amide  1.3060  1.1296  1.0673  1.0631  1.1798  0.9538
# ...                      ...     ...     ...     ...     ...     ...     ...
# 33709  ENSG00000285906_unmod  1.2350  1.0718  1.1190  1.1236  1.2216  1.0523
# 33710  ENSG00000285967_unmod  1.3274  1.5080  1.4076  1.0475  0.9362  0.6334
# 33711  ENSG00000285976_unmod  0.9950  1.1060  1.0426  0.7420  0.7979  0.6980
# 33712  ENSG00000286134_unmod  1.5195  1.6365  1.5152  1.2099  1.2281  1.0346
# ...

# %%
# # Subtract min values from each column
# transformed_data = raw_data_6_updated[min_values.index].apply(lambda x: x - min_values[x.name])
# transformed_min_values = transformed_data.min()
# transformed_max_values = transformed_data.max()

# # Plot min values for each column after transformation
# fig1, ax1 = plt.subplots()
# ax1.plot(transformed_min_values.index, transformed_min_values.values, label='Min', marker='o')
# ax1.set_xticks(range(len(transformed_min_values.index)))
# ax1.set_xticklabels(transformed_min_values.index, rotation=45, ha='right')
# ax1.set_title('Transformed Min Values for Each Column')
# plt.tight_layout()

# # Plot max values for each column after transformation
# fig2, ax2 = plt.subplots()
# ax2.plot(transformed_max_values.index, transformed_max_values.values, label='Max', marker='o')
# ax2.set_xticks(range(len(transformed_max_values.index)))
# ax2.set_xticklabels(transformed_max_values.index, rotation=45, ha='right')
# ax2.set_title('Transformed Max Values for Each Column')
# plt.tight_layout()

# plt.show()
import pandas as pd
import matplotlib.pyplot as plt

# Assuming raw_data_6_updated is already available from previous steps
# Include 'comp_name' explicitly while transforming the data
transformed_data = raw_data_6_updated[['comp_name'] + list(min_values.index)].copy()
transformed_data[min_values.index] = transformed_data[min_values.index].apply(lambda x: x - min_values[x.name])

transformed_min_values = transformed_data[min_values.index].min()
transformed_max_values = transformed_data[min_values.index].max()

# Plot min values for each column after transformation
fig1, ax1 = plt.subplots()
ax1.plot(transformed_min_values.index, transformed_min_values.values, label='Min', marker='o')
ax1.set_xticks(range(len(transformed_min_values.index)))
ax1.set_xticklabels(transformed_min_values.index, rotation=45, ha='right')
ax1.set_title('Transformed Min Values for Each Column')
plt.tight_layout()

# Plot max values for each column after transformation
fig2, ax2 = plt.subplots()
ax2.plot(transformed_max_values.index, transformed_max_values.values, label='Max', marker='o')
ax2.set_xticks(range(len(transformed_max_values.index)))
ax2.set_xticklabels(transformed_max_values.index, rotation=45, ha='right')
ax2.set_title('Transformed Max Values for Each Column')
plt.tight_layout()

plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# transformed_max_values = transformed_data.max()
# columns_to_drop = [col for col in transformed_data.columns if (transformed_data[col] == 0).all()]
# transformed_data = transformed_data.drop(columns=columns_to_drop)
# print("Columns dropped due to all zero values:", columns_to_drop)

# rescaled_data = transformed_data.apply(lambda x: ((x / transformed_max_values[x.name]) * 255).astype('uint8'))
# print(rescaled_data)
# if rescaled_data.isna().any().any() or np.isinf(rescaled_data).any().any():
#     print("NaN or inf values detected after rescaling")

# avg_values_before = transformed_data.mean()
# avg_values_after = rescaled_data.mean()
# min_values_after = rescaled_data.min()
# max_values_after = rescaled_data.max()

# fig1, ax1 = plt.subplots()
# ax1.plot(avg_values_before.index, avg_values_before.values, label='Average Before Rescaling', marker='o')
# ax1.set_xticks(range(len(avg_values_before.index)))
# ax1.set_xticklabels(avg_values_before.index, rotation=45, ha='right')
# ax1.set_title('Average Values for Each Column Before Rescaling')
# ax1.legend()
# plt.tight_layout()

# fig2, ax2 = plt.subplots()
# ax2.plot(avg_values_after.index, avg_values_after.values, label='Average After Rescaling', marker='o', color='red')
# ax2.set_xticks(range(len(avg_values_after.index)))
# ax2.set_xticklabels(avg_values_after.index, rotation=45, ha='right')
# ax2.set_title('Average Values for Each Column After Rescaling')
# ax2.legend()
# plt.tight_layout()

# fig3, ax3 = plt.subplots()
# ax3.plot(max_values_after.index, max_values_after.values, label='Max After Rescaling', marker='o', color='green')
# ax3.set_xticks(range(len(max_values_after.index)))
# ax3.set_xticklabels(max_values_after.index, rotation=45, ha='right')
# ax3.set_title('Max Values for Each Column After Rescaling')
# ax3.legend()
# plt.tight_layout()

# fig4, ax4 = plt.subplots()
# ax4.plot(min_values_after.index, min_values_after.values, label='Min After Rescaling', marker='o', color='blue')
# ax4.set_xticks(range(len(min_values_after.index)))
# ax4.set_xticklabels(min_values_after.index, rotation=45, ha='right')
# ax4.set_title('Min Values for Each Column After Rescaling')
# ax4.legend()
# plt.tight_layout()

# plt.show()
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Get the list of numeric columns
numeric_columns = transformed_data.select_dtypes(include=[np.number]).columns

# Identify columns with all zero values
columns_to_drop = [col for col in numeric_columns if (transformed_data[col] == 0).all()]

# Drop columns that exist in the DataFrame
existing_columns_to_drop = [col for col in columns_to_drop if col in transformed_data.columns]
transformed_data = transformed_data.drop(columns=existing_columns_to_drop)
print("Columns dropped due to all zero values:", existing_columns_to_drop)

# Rescale the numeric columns only
rescaled_data = transformed_data.copy()
rescaled_data[numeric_columns] = transformed_data[numeric_columns].apply(lambda x: ((x / transformed_max_values[x.name]) * 255).astype('uint8'))
print(rescaled_data)

# Check for NaN or inf values after rescaling in numeric columns only
if rescaled_data[numeric_columns].isna().any().any() or np.isinf(rescaled_data[numeric_columns]).any().any():
    print("NaN or inf values detected after rescaling")

avg_values_before = transformed_data[numeric_columns].mean()
avg_values_after = rescaled_data[numeric_columns].mean()
min_values_after = rescaled_data[numeric_columns].min()
max_values_after = rescaled_data[numeric_columns].max()

fig1, ax1 = plt.subplots()
ax1.plot(avg_values_before.index, avg_values_before.values, label='Average Before Rescaling', marker='o')
ax1.set_xticks(range(len(avg_values_before.index)))
ax1.set_xticklabels(avg_values_before.index, rotation=45, ha='right')
ax1.set_title('Average Values for Each Column Before Rescaling')
ax1.legend()
plt.tight_layout()

fig2, ax2 = plt.subplots()
ax2.plot(avg_values_after.index, avg_values_after.values, label='Average After Rescaling', marker='o', color='red')
ax2.set_xticks(range(len(avg_values_after.index)))
ax2.set_xticklabels(avg_values_after.index, rotation=45, ha='right')
ax2.set_title('Average Values for Each Column After Rescaling')
ax2.legend()
plt.tight_layout()

fig3, ax3 = plt.subplots()
ax3.plot(max_values_after.index, max_values_after.values, label='Max After Rescaling', marker='o', color='green')
ax3.set_xticks(range(len(max_values_after.index)))
ax3.set_xticklabels(max_values_after.index, rotation=45, ha='right')
ax3.set_title('Max Values for Each Column After Rescaling')
ax3.legend()
plt.tight_layout()

fig4, ax4 = plt.subplots()
ax4.plot(min_values_after.index, min_values_after.values, label='Min After Rescaling', marker='o', color='blue')
ax4.set_xticks(range(len(min_values_after.index)))
ax4.set_xticklabels(min_values_after.index, rotation=45, ha='right')
ax4.set_title('Min Values for Each Column After Rescaling')
ax4.legend()
plt.tight_layout()

plt.show()
# Out:
# Columns dropped due to all zero values: []
#                    comp_name   23   24   25   26   27   28   29   30   31  \
# 0      ENSG00000000003_amide   85   83   92  104   84   59   29   77   87
# 1      ENSG00000000419_amide  108  113   97   76   78   75   42   89   95
# 2      ENSG00000000457_amide  134  153  148  136  147  137  113  131  133
# 3      ENSG00000000460_amide  166  173  152  125  130  116   83   86   81
# 4      ENSG00000000971_amide  145  127  120  125  148  126   85  147  174
# ...                      ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 33709  ENSG00000285906_unmod  136  120  126  132  154  139  120  126  113
# 33710  ENSG00000285967_unmod  147  173  161  123  117   81   42   64  111
# 33711  ENSG00000285976_unmod  107  124  117   85   99   90  136   97   47
# 33712  ENSG00000286134_unmod  170  189  173  143  155  137  108  128  106
# 33713  ENSG00000286215_unmod  122  108  110  119  137  118   95  135   93
#
# ...

# %%
import pandas as pd

gene_alignments = pd.read_csv('/data/home/mrichte3/RNASeq/gene_alignments5.csv')

def get_log2FC(row, gene_alignments):
    ensembl_id, label = row['comp_name'].rsplit('_', 1)
    log2FC_col = f'log2FC_{label}'
    log2FC_value = gene_alignments.loc[gene_alignments['ensembl_id'] == ensembl_id, log2FC_col].values[0]
    return round(log2FC_value, 4)

rescaled_data['log2FC'] = rescaled_data.apply(lambda row: get_log2FC(row, gene_alignments), axis=1)

rescaled_data.to_csv('rawdata_ref_cif/raw_data_6_rescaled.csv', index=False)

columns_to_drop = [str(i) for i in range(900, 942)]
rescaled_data_dropped = rescaled_data.drop(columns=columns_to_drop)

rescaled_data_dropped.to_csv('rawdata_ref_cif/raw_data_7_rescaled.csv', index=False)
# Out:
# /tmp/ipykernel_3175950/2158835710.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   rescaled_data['log2FC'] = rescaled_data.apply(lambda row: get_log2FC(row, gene_alignments), axis=1)
