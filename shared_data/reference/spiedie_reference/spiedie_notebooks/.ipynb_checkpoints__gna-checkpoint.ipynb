# %%
import subprocess
import os
import shutil
import time
import re
os.environ['PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/bin:' + os.environ['PATH']
if 'LD_LIBRARY_PATH' in os.environ:
    os.environ['LD_LIBRARY_PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/lib:' + os.environ['LD_LIBRARY_PATH']
else:
    os.environ['LD_LIBRARY_PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/lib'
os.environ['GMX_MAXBACKUP'] = '-1'
os.environ['GMX_MAXCONSTRWARN'] = '-1'

def run_command(command, input_text=None, max_chars=100):
    result = subprocess.run(command, capture_output=True, text=True, input=input_text)
    output = result.stdout + result.stderr
    # print(output)
    for line in output.splitlines():
        if "warning" in line.lower() or "fatal" in line.lower() or "random" in line.lower():
            print(line[:max_chars])

def run_mini(command, input_text=None):
    result = subprocess.run(command, capture_output=True, text=True, input=input_text)
    output = result.stdout + result.stderr
    # print(output)
    for line in output.splitlines():
        if ("steepest descents converged to" in line.lower() or
            "fatal" in line.lower() or
            "error" in line.lower() or
            "steepest descents did not converge" in line.lower()):
            print(line)
            match = re.search(r'(\d+) steps', line)
            if match:
                steps = int(match.group(1))
                return steps == 5001
    return False
    
def run_stucture_setup(input_pdb):
    rm_command = "rm *.gro"
    subprocess.run(rm_command, shell=True)
    rm_command = "rm *.tpr"
    subprocess.run(rm_command, shell=True)
    command = ["gmx", "pdb2gmx", "-f", f"{input_pdb}", "-o", "structure_processed.gro", 
               "-p", "topol.top", "-i", "posre.itp"]
    input_text = "6\n1\n"        ############ 6 1 for custom
    run_command(command, input_text)
    command = ["gmx", "editconf", "-f", "structure_processed.gro", "-o", "structure_box.gro", "-c", "-d", "1.0", "-bt", "cubic"]
    run_command(command)
    command = ["gmx", "solvate", "-cp", "structure_box.gro", "-cs", "spc216.gro", "-o", "structure_solv.gro", "-p", "topol.top"]
    run_command(command)
    command = ["gmx", "grompp", "-f", "ions.mdp", "-c", "structure_solv.gro", "-p", "topol.top", "-o", "ions.tpr", "-maxwarn", "3"]
    run_command(command)
    command = ["gmx", "genion", "-s", "ions.tpr", "-o", "structure_solv_ions.gro", "-p", "topol.top", 
               "-pname", "NA", "-nname", "CL", "-neutral", "-conc", "0.15", "-seed", "12345"]
    input_text = "14\n"
    run_command(command, input_text)
    command = ["gmx", "make_ndx", "-f", "structure_solv_ions.gro", "-o", "index.ndx"]
    input_text = "name 19 SOLV\n1 | 12\nname 20 SOLU\nq\n"
    run_command(command, input_text)



pdb_directory = '/data/home/mrichte3/RNASeq/gna/'
pdb_files = sorted([f for f in os.listdir(pdb_directory) if f.endswith('.pdb')])
completed_files = {os.path.splitext(f)[0] for f in os.listdir('/data/home/mrichte3/RNASeq/gna/step5/') if f.endswith('.gro')}
pdb_files = [f for f in pdb_files if os.path.splitext(f)[0] not in completed_files]
print(f"Number of pdb_files to process before truncate: {len(pdb_files)}")
truncate_file = 'ENSG00000105497.pdb'
truncate_index = pdb_files.index(truncate_file) if truncate_file in pdb_files else len(pdb_files)
pdb_files = pdb_files[:truncate_index]
print(f"Number of pdb_files to process after truncate: {len(pdb_files)}")

process_number = 1 
total_files = len(pdb_files)
half_size = total_files // 2
if process_number == 1:
    pdb_files = pdb_files[:half_size]
elif process_number == 2:
    pdb_files = pdb_files[half_size:]

print(f"Number of pdb_files to process: {len(pdb_files)}")

for input_pdb in pdb_files:
    print(f"Current input_pdb: {input_pdb}")
    start_time = time.time()
    run_stucture_setup(os.path.join(pdb_directory, input_pdb))
    if not os.path.exists('structure_solv_ions.gro'):
        continue

    command = ["gmx", "grompp", "-v", "-f", f"step4.0_minimization.mdp", "-o", f"step4.0_minimization.tpr", 
               "-c", f"structure_solv_ions.gro", "-r", f"structure_solv_ions.gro", 
               "-p", "topol.top", "-n", "index.ndx", "-maxwarn", "5"]
    run_mini(command)
    command = ["gmx", "mdrun", "-v", "-deffnm", "step4.0_minimization", "-ntmpi", "1"]
    tries = 0
    while tries < 3 and not run_mini(command):
        tries += 1
    command_grompp = ["gmx", "grompp", "-f", f"step5_production.mdp", "-o", f"step5.tpr",
                      "-c", f"step4.0_minimization.gro", "-p", "topol.top", "-n", "index.ndx", "-maxwarn", "5"]
    run_command(command_grompp)
    command_mdrun = ["gmx", "mdrun", "-v", "-deffnm", "step5", "-ntmpi", "1"]
    run_command(command_mdrun)

    elapsed_time = time.time() - start_time
    print(f"Process {input_pdb} completed in {elapsed_time:.2f} seconds.")
    basename = os.path.splitext(os.path.basename(input_pdb))[0]
    mv_command = ["mv", "step5.gro", f"/data/home/mrichte3/RNASeq/gna/step5/{basename}.gro"]
    run_command(mv_command)
    rm_command = "rm step*.pdb"
    subprocess.run(rm_command, shell=True)
# Out:
# Number of pdb_files to process before truncate: 10880
# Number of pdb_files to process after truncate: 1948
# Number of pdb_files to process: 974
# Current input_pdb: ENSG00000004059.pdb
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# Current input_pdb: ENSG00000005073.pdb
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 38 steps,
# Steepest Descents converged to machine precision in 38 steps,
# Steepest Descents converged to machine precision in 38 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000005073.pdb completed in 21.38 seconds.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 106
#     104 elapsed_time = time.time() - start_time
#     105 print(f"Process {input_pdb} completed in {elapsed_time:.2f} seconds.")
# --> 106 mv_command = ["mv", "step5.gro", f"/data/home/mrichte3/RNASeq/gna/step5/{basename}.gro"]
#     107 run_command(mv_command)
#     108 rm_command = "rm step*.pdb"
#
# NameError: name 'basename' is not defined

# %%
import subprocess
import os
import shutil
import time
import re
os.environ['PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/bin:' + os.environ['PATH']
if 'LD_LIBRARY_PATH' in os.environ:
    os.environ['LD_LIBRARY_PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/lib:' + os.environ['LD_LIBRARY_PATH']
else:
    os.environ['LD_LIBRARY_PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/lib'
os.environ['GMX_MAXBACKUP'] = '-1'
os.environ['GMX_MAXCONSTRWARN'] = '-1'

def run_command(command, input_text=None, max_chars=100):
    result = subprocess.run(command, capture_output=True, text=True, input=input_text)
    output = result.stdout + result.stderr
    # print(output)
    for line in output.splitlines():
        if "warning" in line.lower() or "fatal" in line.lower() or "random" in line.lower():
            print(line[:max_chars])

def run_mini(command, input_text=None):
    result = subprocess.run(command, capture_output=True, text=True, input=input_text)
    output = result.stdout + result.stderr
    # print(output)
    for line in output.splitlines():
        if ("steepest descents converged to" in line.lower() or
            "fatal" in line.lower() or
            "error" in line.lower() or
            "steepest descents did not converge" in line.lower()):
            print(line)
            match = re.search(r'(\d+) steps', line)
            if match:
                steps = int(match.group(1))
                return steps == 5001
    return False
    
def run_stucture_setup(input_pdb):
    rm_command = "rm *.gro"
    subprocess.run(rm_command, shell=True)
    rm_command = "rm *.tpr"
    subprocess.run(rm_command, shell=True)
    command = ["gmx", "pdb2gmx", "-f", f"{input_pdb}", "-o", "structure_processed.gro", 
               "-p", "topol.top", "-i", "posre.itp"]
    input_text = "6\n1\n"        ############ 6 1 for custom
    run_command(command, input_text)
    command = ["gmx", "editconf", "-f", "structure_processed.gro", "-o", "structure_box.gro", "-c", "-d", "1.0", "-bt", "cubic"]
    run_command(command)
    command = ["gmx", "solvate", "-cp", "structure_box.gro", "-cs", "spc216.gro", "-o", "structure_solv.gro", "-p", "topol.top"]
    run_command(command)
    command = ["gmx", "grompp", "-f", "ions.mdp", "-c", "structure_solv.gro", "-p", "topol.top", "-o", "ions.tpr", "-maxwarn", "3"]
    run_command(command)
    command = ["gmx", "genion", "-s", "ions.tpr", "-o", "structure_solv_ions.gro", "-p", "topol.top", 
               "-pname", "NA", "-nname", "CL", "-neutral", "-conc", "0.15", "-seed", "12345"]
    input_text = "14\n"
    run_command(command, input_text)
    command = ["gmx", "make_ndx", "-f", "structure_solv_ions.gro", "-o", "index.ndx"]
    input_text = "name 19 SOLV\n1 | 12\nname 20 SOLU\nq\n"
    run_command(command, input_text)



pdb_directory = '/data/home/mrichte3/RNASeq/gna/'
pdb_files = sorted([f for f in os.listdir(pdb_directory) if f.endswith('.pdb')])
completed_files = {f for f in os.listdir('/data/home/mrichte3/RNASeq/gna/step5/') if f.endswith('.gro')}
for input_pdb in pdb_files:
    basename = os.path.splitext(os.path.basename(input_pdb))[0]
    if basename + '.gro' in completed_files:
        continue
    start_time = time.time()
    run_stucture_setup(os.path.join(pdb_directory, input_pdb))
    if not os.path.exists('structure_solv_ions.gro'):
        continue

    command = ["gmx", "grompp", "-v", "-f", f"step4.0_minimization.mdp", "-o", f"step4.0_minimization.tpr", 
               "-c", f"structure_solv_ions.gro", "-r", f"structure_solv_ions.gro", 
               "-p", "topol.top", "-n", "index.ndx", "-maxwarn", "5"]
    run_mini(command)
    command = ["gmx", "mdrun", "-v", "-deffnm", "step4.0_minimization", "-ntmpi", "1"]
    tries = 0
    while tries < 3 and not run_mini(command):
        tries += 1
    command_grompp = ["gmx", "grompp", "-f", f"step5_production.mdp", "-o", f"step5.tpr",
                      "-c", f"step4.0_minimization.gro", "-p", "topol.top", "-n", "index.ndx", "-maxwarn", "5"]
    run_command(command_grompp)
    command_mdrun = ["gmx", "mdrun", "-v", "-deffnm", "step5", "-ntmpi", "1"]
    run_command(command_mdrun)

    elapsed_time = time.time() - start_time
    print(f"Process {input_pdb} completed in {elapsed_time:.2f} seconds.")
    mv_command = ["mv", "step5.gro", f"/data/home/mrichte3/RNASeq/gna/step5/{basename}.gro"]
    run_command(mv_command)
    rm_command = "rm step*.pdb"
    subprocess.run(rm_command, shell=True)
# Out:
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 38 steps,
# Steepest Descents converged to machine precision in 38 steps,
# Steepest Descents converged to machine precision in 38 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000005073.pdb completed in 21.35 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000009307.pdb completed in 197.24 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4374 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000009780.pdb completed in 247.33 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3986 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000009830.pdb completed in 247.41 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000009844.pdb completed in 197.33 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4949 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000009950.pdb completed in 263.19 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3388 steps,
# Steepest Descents converged to machine precision in 4582 steps,
# Steepest Descents converged to machine precision in 3884 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000009954.pdb completed in 283.08 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4444 steps,
# Steepest Descents converged to machine precision in 3135 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010017.pdb completed in 286.41 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010072.pdb completed in 201.54 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3864 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010165.pdb completed in 191.52 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010219.pdb completed in 201.85 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3088 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010244.pdb completed in 240.78 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010256.pdb completed in 197.26 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4356 steps,
# Steepest Descents converged to machine precision in 4161 steps,
# Steepest Descents converged to machine precision in 3860 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010270.pdb completed in 287.33 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3760 steps,
# Steepest Descents converged to machine precision in 3462 steps,
# Steepest Descents converged to machine precision in 4658 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010278.pdb completed in 279.42 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010292.pdb completed in 206.71 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010322.pdb completed in 201.05 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010361.pdb completed in 202.91 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4647 steps,
# Steepest Descents converged to machine precision in 4894 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010404.pdb completed in 304.58 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4479 steps,
# Steepest Descents converged to machine precision in 4872 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010539.pdb completed in 306.88 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010704.pdb completed in 201.21 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010803.pdb completed in 188.43 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3599 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000010818.pdb completed in 241.74 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4097 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011007.pdb completed in 251.17 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4393 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011009.pdb completed in 249.35 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011021.pdb completed in 202.89 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011028.pdb completed in 199.67 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011105.pdb completed in 199.82 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011114.pdb completed in 207.93 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011132.pdb completed in 202.11 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011143.pdb completed in 190.95 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011201.pdb completed in 208.33 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4515 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011243.pdb completed in 251.37 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3442 steps,
# Steepest Descents converged to machine precision in 4652 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011258.pdb completed in 285.55 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4598 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011260.pdb completed in 248.42 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4543 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011275.pdb completed in 255.29 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011304.pdb completed in 203.56 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011376.pdb completed in 206.44 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011405.pdb completed in 187.61 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3941 steps,
# Steepest Descents converged to machine precision in 3222 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011422.pdb completed in 288.77 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011426.pdb completed in 199.72 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011451.pdb completed in 195.72 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011454.pdb completed in 215.87 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011465.pdb completed in 195.84 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 38 steps,
# Steepest Descents converged to machine precision in 38 steps,
# Steepest Descents converged to machine precision in 38 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011478.pdb completed in 21.01 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011485.pdb completed in 202.13 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4979 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011523.pdb completed in 258.97 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011566.pdb completed in 202.25 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011638.pdb completed in 196.41 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4046 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000011677.pdb completed in 244.09 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3696 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012048.pdb completed in 245.41 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4596 steps,
# Steepest Descents converged to machine precision in 4014 steps,
# Steepest Descents converged to machine precision in 4066 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012061.pdb completed in 298.56 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4498 steps,
# Steepest Descents converged to machine precision in 2541 steps,
# Steepest Descents converged to machine precision in 3672 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012171.pdb completed in 269.62 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012174.pdb completed in 201.70 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012211.pdb completed in 204.99 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4528 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012232.pdb completed in 248.98 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4691 steps,
# Steepest Descents converged to machine precision in 4340 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012660.pdb completed in 301.17 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# GROMACS reminds you: "error: too many template-parameter-lists" (g++)
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012822.pdb completed in 202.33 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4666 steps,
# Steepest Descents converged to machine precision in 4585 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012963.pdb completed in 302.26 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 3527 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000012983.pdb completed in 244.10 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013275.pdb completed in 202.23 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013288.pdb completed in 200.10 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013306.pdb completed in 207.56 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4349 steps,
# Steepest Descents converged to machine precision in 4253 steps,
# Steepest Descents converged to machine precision in 4422 steps,
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013364.pdb completed in 284.36 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013374.pdb completed in 199.10 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013375.pdb completed in 202.14 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4562 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013392.pdb completed in 250.83 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013441.pdb completed in 196.17 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013503.pdb completed in 197.36 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Fatal error:
# rm: cannot remove '*.tpr': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013561.pdb completed in 200.39 seconds.
# rm: cannot remove 'step*.pdb': No such file or directory
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013563.pdb completed in 203.78 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# Steepest Descents converged to machine precision in 4733 steps,
# Steepest Descents converged to machine precision in 4254 steps,
# Steepest Descents did not converge to Fmax < 0 in 5001 steps.
# WARNING 1 [file topol.top, line 52]:
# There was 1 WARNING
# Setting the maximum number of constraint warnings to 2147483647
# Process ENSG00000013573.pdb completed in 311.42 seconds.
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Duplicate line found in or between hackblock and rtp entries
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
# WARNING 1 [file topol.top, line 50]:
# WARNING 2 [file topol.top, line 50]:
# There were 2 WARNINGs
# Using random seed 12345.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 81
#      79 command = ["gmx", "mdrun", "-v", "-deffnm", "step4.0_minimization", "-ntmpi", "1"]
#      80 tries = 0
# ---> 81 while tries < 3 and not run_mini(command):
#      82     tries += 1
#      83 command_grompp = ["gmx", "grompp", "-f", f"step5_production.mdp", "-o", f"step5.tpr",
#      84                   "-c", f"step4.0_minimization.gro", "-p", "topol.top", "-n", "index.ndx", "-maxwarn", "5"]
#
# Cell In[2], line 23, in run_mini(command, input_text)
#      22 def run_mini(command, input_text=None):
# ---> 23     result = subprocess.run(command, capture_output=True, text=True, input=input_text)
#      24     output = result.stdout + result.stderr
#      25     # print(output)
#
# File ~/miniconda3/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/miniconda3/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~/miniconda3/lib/python3.12/subprocess.py:2113, in Popen._communicate(self, input, endtime, orig_timeout)
#    2106     self._check_timeout(endtime, orig_timeout,
#    2107                         stdout, stderr,
#    2108                         skip_check_and_raise=True)
#    2109     raise RuntimeError(  # Impossible :)
#    2110         '_check_timeout(..., skip_check_and_raise=True) '
#    2111         'failed to raise TimeoutExpired.')
# -> 2113 ready = selector.select(timeout)
#    2114 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2116 # XXX Rewrite these to use non-blocking I/O on the file
#    2117 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
