# %%
import subprocess
import os
import shutil
import time
os.environ['PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/bin:' + os.environ['PATH']
if 'LD_LIBRARY_PATH' in os.environ:
    os.environ['LD_LIBRARY_PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/lib:' + os.environ['LD_LIBRARY_PATH']
else:
    os.environ['LD_LIBRARY_PATH'] = '/data/home/mrichte3/gromacs-2024.2/install/lib'
os.environ['GMX_MAXBACKUP'] = '-1'
os.environ['GMX_MAXCONSTRWARN'] = '-1'

import subprocess
import re

def run_mini(command, input_text=None):
    result = subprocess.run(command, capture_output=True, text=True, input=input_text)
    output = result.stdout + result.stderr
    print(output)
    for line in output.splitlines():
        if ("steepest descents converged to" in line.lower() or
            "fatal" in line.lower() or
            "error" in line.lower() or
            "steepest descents did not converge" in line.lower()):
            print(line)
            match = re.search(r'(\d+) steps', line)
            if match:
                steps = int(match.group(1))
                return steps == 5001
    return False

mini_prefix = "step4.0_minimization"
equi_prefix = "step4.0_minimization"
prod_prefix = "step5_production"
prod_step = "step5"

gro_directory = '/data/home/mrichte3/RNASeq/amide/'
gro_files = [f for f in os.listdir(gro_directory) if f.endswith('.gro')]
for input_gro in gro_files:
    start_time = time.time()
    command = ["gmx", "grompp", "-v", "-f", f"{mini_prefix}.mdp", "-o", f"{mini_prefix}.tpr", 
               "-c", f"{input_gro}", "-r", f"{input_gro}", 
               "-p", "topol.top", "-n", "index.ndx", "-maxwarn", "5"]
    run_mini(command)
    command = ["gmx", "mdrun", "-v", "-deffnm", mini_prefix, "-ntmpi", "1"]
    while not run_mini(command):
        pass
    new_file = "step4.0_minimization.gro"
    basename = os.path.splitext(os.path.basename(input_gro))[0]
    target_path = f"/data/home/mrichte3/RNASeq/amide/mini_output/{basename}.gro"
    if not os.path.exists(new_file):
        print(f"A problem occurred: {new_file} does not exist.#####################################################################")
    else:
        shutil.move(new_file, target_path)
##################

    elapsed_time = time.time() - start_time
    print(f"Process {basename} completed in {elapsed_time:.2f} seconds.")
# Out:
#                       :-) GROMACS - gmx grompp, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx grompp -v -f step4.0_minimization.mdp -o step4.0_minimization.tpr -c ENSG00000000003.gro -r ENSG00000000003.gro -p topol.top -n index.ndx -maxwarn 5
#
#
# -------------------------------------------------------
# Program:     gmx grompp, version 2024.2
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -c
#     File 'ENSG00000000003.gro' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#   In command-line option -r
#     File 'ENSG00000000003.gro' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
#       (call to fopen() returned error code 2)
#       (call to fopen() returned error code 2)
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
#                       :-) GROMACS - gmx mdrun, 2024.2 (-:
#
# Executable:   /data/home/mrichte3/gromacs-2024.2/install/bin/gmx
# Data prefix:  /data/home/mrichte3/gromacs-2024.2/install
# Working dir:  /data/home/mrichte3/RNASeq/test_alignment/md/working_folder
# Command line:
#   gmx mdrun -v -deffnm step4.0_minimization -ntmpi 1
#
#
# -------------------------------------------------------
# Program:     gmx mdrun, version 2024.2
# Source file: src/gromacs/options/options.cpp (line 177)
# Function:    void gmx::internal::OptionSectionImpl::finish()
#
# Error in user input:
# Invalid input values
#   In option s
#     Required option was not provided, and the default file 'topol' does not
#     exist or is not accessible.
#     The following extensions were tried to complete the file name:
#       .tpr
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
#
# Error in user input:
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 46
#      44 run_mini(command)
#      45 command = ["gmx", "mdrun", "-v", "-deffnm", mini_prefix, "-ntmpi", "1"]
# ---> 46 while not run_mini(command):
#      47     pass
#      48 new_file = "step4.0_minimization.gro"
#
# Cell In[1], line 17, in run_mini(command, input_text)
#      16 def run_mini(command, input_text=None):
# ---> 17     result = subprocess.run(command, capture_output=True, text=True, input=input_text)
#      18     output = result.stdout + result.stderr
#      19     print(output)
#
# File ~/miniconda3/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/miniconda3/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~/miniconda3/lib/python3.12/subprocess.py:2113, in Popen._communicate(self, input, endtime, orig_timeout)
#    2106     self._check_timeout(endtime, orig_timeout,
#    2107                         stdout, stderr,
#    2108                         skip_check_and_raise=True)
#    2109     raise RuntimeError(  # Impossible :)
#    2110         '_check_timeout(..., skip_check_and_raise=True) '
#    2111         'failed to raise TimeoutExpired.')
# -> 2113 ready = selector.select(timeout)
#    2114 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2116 # XXX Rewrite these to use non-blocking I/O on the file
#    2117 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
